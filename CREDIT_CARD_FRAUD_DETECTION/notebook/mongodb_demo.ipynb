# %%
print("Suraj")

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\asus\.cache\kagglehub\datasets\mlg-ulb\creditcardfraud\versions\3\creditcard.csv")
df.head(5)

# %%
df.shape

# %%
df.columns

# %%
data = df.to_dict(orient="records")
data

# %%
len(data)

# %%
DB_NAME = "creditcardproject"   # mongodb me dataset create krte time jo name diya tha voo
COLLECTION_NAME = "credit_data" # Khud se name de rahe hai yani dataset ke aandar ek cluster name de kr uske aandar data save kr rahe hai 
CONNECTION_URL = "MongoDB url"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")

# %%
df = pd.DataFrame(list(collection.find()))
df.head()

# %%
len(df)

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
