# %%
print("Suraj")

# %%
'''
mongodb+srv://srsuraj009_db_user:suraj@cluster0.2cqs0nq.mongodb.net/?appName=Cluster0
'''

# %%
import pandas as pd

# %% [markdown]
# Niche diy gye method ka use krke hm direct kaggle se dataset ko upload ya connet kr sakte hai . eske liy datset ko apne local pc me manually download krne ki jarurat nahi hai.
#
#
# Esko run run krne se pahle apne terminal me "kagglehub" ko install kr le.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("moro23/easyvisa-dataset")

print("Path to dataset files:", path)

# %%
import os

# Jo path kagglehub ne diya hai use ek variable mein rakhein
dataset_path = r"C:\Users\asus\.cache\kagglehub\datasets\moro23\easyvisa-dataset\versions\1"

# Folder ki files ki list dekhein
print(os.listdir(dataset_path))

# %%
file_name = "EasyVisa.csv"
full_df_path = os.path.join(path, file_name)

# %%
df = pd.read_csv(full_df_path)

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
data = df.to_dict(orient="records")
data

# %%
len(data)

# %%
DB_NAME = "US_VISA"
COLLECTION_NAME = "visa_data"
CONNECTION_URL = "mongodb+srv://srsuraj009_db_user:suraj@cluster0.2cqs0nq.mongodb.net/?appName=Cluster0"

# %%
import pymongo

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")

# %%
df = pd.DataFrame(list(collection.find()))
df.head()

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()

# %%
export MONGODB_URL="mongodb+srv://srsuraj009_db_user:suraj@cluster0.2cqs0nq.mongodb.net/?appName=Cluster0"
